# %% [markdown]
# <a href="https://colab.research.google.com/github/naosadhossen/fakenewsdetection/blob/main/class_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import re
import matplotlib.pyplot as plt

# Load the FakeNewsCorpus dataset into a Pandas dataframe
# Assuming the dataset is stored in a CSV file named 'news-data-12p.csv'
fake_news_df = pd.read_csv('/content/drive/MyDrive/LUT/ISS/labeled-new-strictness-high.csv')

# Drop rows with NaN values in the 'content' column
fake_news_df = fake_news_df.dropna(subset=['content', 'type'])

# 1. Distribution of Classes
class_distribution = fake_news_df['type'].value_counts()
print("Class Distribution:")
print(class_distribution)

#Visualization
plt.figure(figsize=(10, 6))
class_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Classes')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()
# Out:
# Class Distribution:
# type
# political                     237752
# reliable                      187437
# bias                          112023
# fake                           87767
# conspiracy                     81730
# rumor                          47663
# unknown                        36390
# unreliable                     29444
# clickbait                      22804
# junksci                        11393
# satire                         11123
# hate                            7510
#  including Iraq                 4419
# 2018-02-08 19:18:34.468038      3968
# 2018-02-08 19:18:34.468066      3222
# ” said Linton Roberts           3196
# 2017-11-10T11:18:44.524042      1390
# 2018-02-10 13:43:39.521661         1
# Name: count, dtype: int64
